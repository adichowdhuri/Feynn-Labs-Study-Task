# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r'mcdonalds.csv'
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
modified_file_path = r'mcdonalds_modified.csv'
modified_data = pd.read_csv(modified_file_path)

# %%
# DATA KEY
# YES = 1 NO = 0
# MALE = 1 FEMALE = 0
# VISIT FREQUENCY HAS BEEN CHANGED TO VISITS PER YEAR
# MORE THAN ONCE A WEEK: 96
# ONCE A WEEK: 48
# ONCE A MONTH: 12
# ONCE IN THREE MONTHS: 4
# ONCE A YEAR: 1
# NEVER: 0

# %%
modified_data.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting  Like  Age  Visits/year  Gender
# 0        0           0    -3   61            4  Female
# 1        0           0     2   51            4  Female
# 2        1           0     1   62            4  Female
# 3        0           1     4   69           48  Female
# 4        1           0     2   49           12    Male

# %%
modified_data.describe()
# Out:
#              yummy   convenient        spicy    fattening       greasy  \
# count  1453.000000  1453.000000  1453.000000  1453.000000  1453.000000
# mean      0.552650     0.907777     0.093599     0.867171     0.526497
# std       0.497391     0.289440     0.291371     0.339506     0.499469
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     1.000000     0.000000
# 50%       1.000000     1.000000     0.000000     1.000000     1.000000
# 75%       1.000000     1.000000     0.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#               fast        cheap        tasty    expensive      healthy  \
# count  1453.000000  1453.000000  1453.000000  1453.000000  1453.000000
# mean      0.900206     0.598761     0.644184     0.357880     0.198899
# std       0.299828     0.490318     0.478925     0.479542     0.399309
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     1.000000     1.000000     0.000000     0.000000
# 75%       1.000000     1.000000     1.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#         disgusting         Like          Age  Visits/year       Gender
# count  1453.000000  1453.000000  1453.000000  1453.000000  1453.000000
# mean      0.242946     0.777013    44.604955    16.071576     0.457674
# std       0.429010     3.116842    14.221178    22.464244     0.498377
# min       0.000000    -5.000000    18.000000     0.000000     0.000000
# 25%       0.000000    -1.000000    33.000000     1.000000     0.000000
# 50%       0.000000     1.000000    45.000000    12.000000     0.000000
# 75%       0.000000     3.000000    57.000000    12.000000     1.000000
# max       1.000000     5.000000    71.000000    96.000000     1.000000

# %%
labels = ['Male','Female']
count = [modified_data.query('Gender == "Female"').Gender.count(),modified_data.query('Gender == "Male"').Gender.count()]
#colors
colors = ['#ff9999','#66b3ff']

plt.figure(figsize=(6,6)) 

centre_circle = plt.Circle((0,0),0.70,fc='white')
plt.pie(count, colors = colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85,explode=explode)
fig=plt.gcf()
plt.axis('equal')
fig.patch.set_facecolor('white')
plt.tight_layout()
fig.gca().add_artist(centre_circle)
plt.show()
